# %% [markdown]
# <a href="https://colab.research.google.com/github/RonakMehta21/Advanced-Deep-Learning/blob/master/Assignment4/Keras_MMOE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Multi-gate Mixture-of-Experts
# This notebook implements [Multi-gate Mixture-of-Experts](http://www.kdd.org/kdd2018/accepted-papers/view/modeling-task-relationships-in-multi-task-learning-with-multi-gate-mixture-) in Keras. MMOE is demonstrated by leveraging [Census-Income (KDD) Data Set](https://archive.ics.uci.edu/ml/datasets/Census-Income+(KDD))

# %%
# !pip install -q --no-color keras==2.2.4
# !pip install -q --no-color tensorflow==1.15.4
# Out:
#      |████████████████████████████████| 317kB 11.7MB/s
#      |████████████████████████████████| 51kB 8.0MB/s
#      |████████████████████████████████| 110.5MB 36kB/s
#      |████████████████████████████████| 3.8MB 49.1MB/s
#      |████████████████████████████████| 512kB 48.4MB/s
#   Building wheel for gast (setup.py) ... done
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.

# %%
"""
Multi-gate Mixture-of-Experts demo with census income data.
Copyright (c) 2018 Drawbridge, Inc
Licensed under the MIT License (see LICENSE for details)
Written by Alvin Deng
"""

import random

import pandas as pd
import numpy as np
import tensorflow as tf
from keras import backend as K
from keras.optimizers import Adam
from keras.initializers import VarianceScaling
from keras.layers import Input, Dense
from keras.models import Model
from keras.utils import to_categorical
from keras.callbacks import Callback
from sklearn.metrics import roc_auc_score
# Out:
# Using TensorFlow backend.

# %%
#@title Multi-gate Mixture-of-Experts model.
"""
Multi-gate Mixture-of-Experts model implementation.
Copyright (c) 2018 Drawbridge, Inc
Licensed under the MIT License (see LICENSE for details)
Written by Alvin Deng
"""

from keras import backend as K
from keras import activations, initializers, regularizers, constraints
from keras.engine.topology import Layer, InputSpec


class MMoE(Layer):
    """
    Multi-gate Mixture-of-Experts model.
    """

    def __init__(self,
                 units,
                 num_experts,
                 num_tasks,
                 use_expert_bias=True,
                 use_gate_bias=True,
                 expert_activation='relu',
                 gate_activation='softmax',
                 expert_bias_initializer='zeros',
                 gate_bias_initializer='zeros',
                 expert_bias_regularizer=None,
                 gate_bias_regularizer=None,
                 expert_bias_constraint=None,
                 gate_bias_constraint=None,
                 expert_kernel_initializer='VarianceScaling',
                 gate_kernel_initializer='VarianceScaling',
                 expert_kernel_regularizer=None,
                 gate_kernel_regularizer=None,
                 expert_kernel_constraint=None,
                 gate_kernel_constraint=None,
                 activity_regularizer=None,
                 **kwargs):
        """
         Method for instantiating MMoE layer.
        :param units: Number of hidden units
        :param num_experts: Number of experts
        :param num_tasks: Number of tasks
        :param use_expert_bias: Boolean to indicate the usage of bias in the expert weights
        :param use_gate_bias: Boolean to indicate the usage of bias in the gate weights
        :param expert_activation: Activation function of the expert weights
        :param gate_activation: Activation function of the gate weights
        :param expert_bias_initializer: Initializer for the expert bias
        :param gate_bias_initializer: Initializer for the gate bias
        :param expert_bias_regularizer: Regularizer for the expert bias
        :param gate_bias_regularizer: Regularizer for the gate bias
        :param expert_bias_constraint: Constraint for the expert bias
        :param gate_bias_constraint: Constraint for the gate bias
        :param expert_kernel_initializer: Initializer for the expert weights
        :param gate_kernel_initializer: Initializer for the gate weights
        :param expert_kernel_regularizer: Regularizer for the expert weights
        :param gate_kernel_regularizer: Regularizer for the gate weights
        :param expert_kernel_constraint: Constraint for the expert weights
        :param gate_kernel_constraint: Constraint for the gate weights
        :param activity_regularizer: Regularizer for the activity
        :param kwargs: Additional keyword arguments for the Layer class
        """
        # Hidden nodes parameter
        self.units = units
        self.num_experts = num_experts
        self.num_tasks = num_tasks

        # Weight parameter
        self.expert_kernels = None
        self.gate_kernels = None
        self.expert_kernel_initializer = initializers.get(expert_kernel_initializer)
        self.gate_kernel_initializer = initializers.get(gate_kernel_initializer)
        self.expert_kernel_regularizer = regularizers.get(expert_kernel_regularizer)
        self.gate_kernel_regularizer = regularizers.get(gate_kernel_regularizer)
        self.expert_kernel_constraint = constraints.get(expert_kernel_constraint)
        self.gate_kernel_constraint = constraints.get(gate_kernel_constraint)

        # Activation parameter
        self.expert_activation = activations.get(expert_activation)
        self.gate_activation = activations.get(gate_activation)

        # Bias parameter
        self.expert_bias = None
        self.gate_bias = None
        self.use_expert_bias = use_expert_bias
        self.use_gate_bias = use_gate_bias
        self.expert_bias_initializer = initializers.get(expert_bias_initializer)
        self.gate_bias_initializer = initializers.get(gate_bias_initializer)
        self.expert_bias_regularizer = regularizers.get(expert_bias_regularizer)
        self.gate_bias_regularizer = regularizers.get(gate_bias_regularizer)
        self.expert_bias_constraint = constraints.get(expert_bias_constraint)
        self.gate_bias_constraint = constraints.get(gate_bias_constraint)

        # Activity parameter
        self.activity_regularizer = regularizers.get(activity_regularizer)

        # Keras parameter
        self.input_spec = InputSpec(min_ndim=2)
        self.supports_masking = True

        super(MMoE, self).__init__(**kwargs)

    def build(self, input_shape):
        """
        Method for creating the layer weights.
        :param input_shape: Keras tensor (future input to layer)
                            or list/tuple of Keras tensors to reference
                            for weight shape computations
        """
        assert input_shape is not None and len(input_shape) >= 2

        input_dimension = input_shape[-1]

        # Initialize expert weights (number of input features * number of units per expert * number of experts)
        self.expert_kernels = self.add_weight(
            name='expert_kernel',
            shape=(input_dimension, self.units, self.num_experts),
            initializer=self.expert_kernel_initializer,
            regularizer=self.expert_kernel_regularizer,
            constraint=self.expert_kernel_constraint,
        )

        # Initialize expert bias (number of units per expert * number of experts)
        if self.use_expert_bias:
            self.expert_bias = self.add_weight(
                name='expert_bias',
                shape=(self.units, self.num_experts),
                initializer=self.expert_bias_initializer,
                regularizer=self.expert_bias_regularizer,
                constraint=self.expert_bias_constraint,
            )

        # Initialize gate weights (number of input features * number of experts * number of tasks)
        self.gate_kernels = [self.add_weight(
            name='gate_kernel_task_{}'.format(i),
            shape=(input_dimension, self.num_experts),
            initializer=self.gate_kernel_initializer,
            regularizer=self.gate_kernel_regularizer,
            constraint=self.gate_kernel_constraint
        ) for i in range(self.num_tasks)]

        # Initialize gate bias (number of experts * number of tasks)
        if self.use_gate_bias:
            self.gate_bias = [self.add_weight(
                name='gate_bias_task_{}'.format(i),
                shape=(self.num_experts,),
                initializer=self.gate_bias_initializer,
                regularizer=self.gate_bias_regularizer,
                constraint=self.gate_bias_constraint
            ) for i in range(self.num_tasks)]

        self.input_spec = InputSpec(min_ndim=2, axes={-1: input_dimension})

        super(MMoE, self).build(input_shape)

    def call(self, inputs, **kwargs):
        """
        Method for the forward function of the layer.
        :param inputs: Input tensor
        :param kwargs: Additional keyword arguments for the base method
        :return: A tensor
        """
        gate_outputs = []
        final_outputs = []

        # f_{i}(x) = activation(W_{i} * x + b), where activation is ReLU according to the paper
        expert_outputs = K.tf.tensordot(a=inputs, b=self.expert_kernels, axes=1)
        # Add the bias term to the expert weights if necessary
        if self.use_expert_bias:
            expert_outputs = K.bias_add(x=expert_outputs, bias=self.expert_bias)
        expert_outputs = self.expert_activation(expert_outputs)

        # g^{k}(x) = activation(W_{gk} * x + b), where activation is softmax according to the paper
        for index, gate_kernel in enumerate(self.gate_kernels):
            gate_output = K.dot(x=inputs, y=gate_kernel)
            # Add the bias term to the gate weights if necessary
            if self.use_gate_bias:
                gate_output = K.bias_add(x=gate_output, bias=self.gate_bias[index])
            gate_output = self.gate_activation(gate_output)
            gate_outputs.append(gate_output)

        # f^{k}(x) = sum_{i=1}^{n}(g^{k}(x)_{i} * f_{i}(x))
        for gate_output in gate_outputs:
            expanded_gate_output = K.expand_dims(gate_output, axis=1)
            weighted_expert_output = expert_outputs * K.repeat_elements(expanded_gate_output, self.units, axis=1)
            final_outputs.append(K.sum(weighted_expert_output, axis=2))

        return final_outputs

    def compute_output_shape(self, input_shape):
        """
        Method for computing the output shape of the MMoE layer.
        :param input_shape: Shape tuple (tuple of integers)
        :return: List of input shape tuple where the size of the list is equal to the number of tasks
        """
        assert input_shape is not None and len(input_shape) >= 2

        output_shape = list(input_shape)
        output_shape[-1] = self.units
        output_shape = tuple(output_shape)

        return [output_shape for _ in range(self.num_tasks)]

    def get_config(self):
        """
        Method for returning the configuration of the MMoE layer.
        :return: Config dictionary
        """
        config = {
            'units': self.units,
            'num_experts': self.num_experts,
            'num_tasks': self.num_tasks,
            'use_expert_bias': self.use_expert_bias,
            'use_gate_bias': self.use_gate_bias,
            'expert_activation': activations.serialize(self.expert_activation),
            'gate_activation': activations.serialize(self.gate_activation),
            'expert_bias_initializer': initializers.serialize(self.expert_bias_initializer),
            'gate_bias_initializer': initializers.serialize(self.gate_bias_initializer),
            'expert_bias_regularizer': regularizers.serialize(self.expert_bias_regularizer),
            'gate_bias_regularizer': regularizers.serialize(self.gate_bias_regularizer),
            'expert_bias_constraint': constraints.serialize(self.expert_bias_constraint),
            'gate_bias_constraint': constraints.serialize(self.gate_bias_constraint),
            'expert_kernel_initializer': initializers.serialize(self.expert_kernel_initializer),
            'gate_kernel_initializer': initializers.serialize(self.gate_kernel_initializer),
            'expert_kernel_regularizer': regularizers.serialize(self.expert_kernel_regularizer),
            'gate_kernel_regularizer': regularizers.serialize(self.gate_kernel_regularizer),
            'expert_kernel_constraint': constraints.serialize(self.expert_kernel_constraint),
            'gate_kernel_constraint': constraints.serialize(self.gate_kernel_constraint),
            'activity_regularizer': regularizers.serialize(self.activity_regularizer)
        }
        base_config = super(MMoE, self).get_config()

        return dict(list(base_config.items()) + list(config.items()))

# %%
SEED = 1

# Fix numpy seed for reproducibility
np.random.seed(SEED)

# Fix random seed for reproducibility
random.seed(SEED)

# Fix TensorFlow graph-level seed for reproducibility
tf.set_random_seed(SEED)
tf_session = tf.Session(graph=tf.get_default_graph())
K.set_session(tf_session)

# %% [markdown]
# Simple callback to print out ROC-AUC

# %%
class ROCCallback(Callback):
    def __init__(self, training_data, validation_data, test_data):
        self.train_X = training_data[0]
        self.train_Y = training_data[1]
        self.validation_X = validation_data[0]
        self.validation_Y = validation_data[1]
        self.test_X = test_data[0]
        self.test_Y = test_data[1]

    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        train_prediction = self.model.predict(self.train_X)
        validation_prediction = self.model.predict(self.validation_X)
        test_prediction = self.model.predict(self.test_X)

        # Iterate through each task and output their ROC-AUC across different datasets
        for index, output_name in enumerate(self.model.output_names):
            train_roc_auc = roc_auc_score(self.train_Y[index], train_prediction[index])
            validation_roc_auc = roc_auc_score(self.validation_Y[index], validation_prediction[index])
            test_roc_auc = roc_auc_score(self.test_Y[index], test_prediction[index])
            print(
                'ROC-AUC-{}-Train: {} ROC-AUC-{}-Validation: {} ROC-AUC-{}-Test: {}'.format(
                    output_name, round(train_roc_auc, 4),
                    output_name, round(validation_roc_auc, 4),
                    output_name, round(test_roc_auc, 4)
                )
            )

        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

# %% [markdown]
# Data Preprocessing

# %%
def data_preparation():
    # The column names are from
    # https://www2.1010data.com/documentationcenter/prod/Tutorials/MachineLearningExamples/CensusIncomeDataSet.html
    column_names = ['age', 'class_worker', 'det_ind_code', 'det_occ_code', 'education', 'wage_per_hour', 'hs_college',
                    'marital_stat', 'major_ind_code', 'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member',
                    'unemp_reason', 'full_or_part_emp', 'capital_gains', 'capital_losses', 'stock_dividends',
                    'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat', 'det_hh_summ',
                    'instance_weight', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                    'num_emp', 'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                    'own_or_self', 'vet_question', 'vet_benefits', 'weeks_worked', 'year', 'income_50k']

    # Load the dataset in Pandas
    train_df = pd.read_csv(
        'https://github.com/RonakMehta21/Advanced-Deep-Learning/blob/master/Assignment4/Census_income_dataset/census-income.data.gz?raw=true',
        compression='gzip',
        error_bad_lines=False,
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )
    other_df = pd.read_csv(
        'https://github.com/RonakMehta21/Advanced-Deep-Learning/blob/master/Assignment4/Census_income_dataset/census-income.test.gz?raw=true',
        compression='gzip',
        error_bad_lines=False,
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )

    # First group of tasks according to the paper
    label_columns = ['income_50k', 'marital_stat']

    # One-hot encoding categorical columns
    categorical_columns = ['class_worker', 'det_ind_code', 'det_occ_code', 'education', 'hs_college', 'major_ind_code',
                           'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member', 'unemp_reason',
                           'full_or_part_emp', 'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat',
                           'det_hh_summ', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                           'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                           'vet_question']
    train_raw_labels = train_df[label_columns]
    other_raw_labels = other_df[label_columns]
    transformed_train = pd.get_dummies(train_df.drop(label_columns, axis=1), columns=categorical_columns)
    transformed_other = pd.get_dummies(other_df.drop(label_columns, axis=1), columns=categorical_columns)

    # Filling the missing column in the other set
    transformed_other['det_hh_fam_stat_ Grandchild <18 ever marr not in subfamily'] = 0

    # One-hot encoding categorical labels
    train_income = to_categorical((train_raw_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    train_marital = to_categorical((train_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)
    other_income = to_categorical((other_raw_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    other_marital = to_categorical((other_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)

    dict_outputs = {
        'income': train_income.shape[1],
        'marital': train_marital.shape[1]
    }
    dict_train_labels = {
        'income': train_income,
        'marital': train_marital
    }
    dict_other_labels = {
        'income': other_income,
        'marital': other_marital
    }
    output_info = [(dict_outputs[key], key) for key in sorted(dict_outputs.keys())]

    # Split the other dataset into 1:1 validation to test according to the paper
    validation_indices = transformed_other.sample(frac=0.5, replace=False, random_state=SEED).index
    test_indices = list(set(transformed_other.index) - set(validation_indices))
    validation_data = transformed_other.iloc[validation_indices]
    validation_label = [dict_other_labels[key][validation_indices] for key in sorted(dict_other_labels.keys())]
    test_data = transformed_other.iloc[test_indices]
    test_label = [dict_other_labels[key][test_indices] for key in sorted(dict_other_labels.keys())]
    train_data = transformed_train
    train_label = [dict_train_labels[key] for key in sorted(dict_train_labels.keys())]

    return train_data, train_label, validation_data, validation_label, test_data, test_label, output_info

# %% [markdown]
# Load the data

# %%
train_data, train_label, validation_data, validation_label, test_data, test_label, output_info = data_preparation()
num_features = train_data.shape[1]

print('Training data shape = {}'.format(train_data.shape))
print('Validation data shape = {}'.format(validation_data.shape))
print('Test data shape = {}'.format(test_data.shape))
# Out:
# Training data shape = (199523, 499)
# Validation data shape = (49881, 499)
# Test data shape = (49881, 499)

# %% [markdown]
# Define the model

# %%
# Set up the input layer
input_layer = Input(shape=(num_features,))

# Set up MMoE layer
mmoe_layers = MMoE(
    units=4,
    num_experts=8,
    num_tasks=2
)(input_layer)

output_layers = []

# Build tower layer from MMoE layer
for index, task_layer in enumerate(mmoe_layers):
    tower_layer = Dense(
        units=8,
        activation='relu',
        kernel_initializer=VarianceScaling())(task_layer)
    output_layer = Dense(
        units=output_info[index][0],
        name=output_info[index][1],
        activation='softmax',
        kernel_initializer=VarianceScaling())(tower_layer)
    output_layers.append(output_layer)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.

# %% [markdown]
# Compile the model

# %%
model = Model(inputs=[input_layer], outputs=output_layers)
adam_optimizer = Adam()
model.compile(
    loss={'income': 'binary_crossentropy', 'marital': 'binary_crossentropy'},
    optimizer=adam_optimizer,
    metrics=['accuracy']
)

# Print out model architecture summary
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 499)          0
# __________________________________________________________________________________________________
# m_mo_e_1 (MMoE)                 [(None, 4), (None, 4 24000       input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            40          m_mo_e_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8)            40          m_mo_e_1[0][1]
# __________________________________________________________________________________________________
# income (Dense)                  (None, 2)            18          dense_1[0][0]
# __________________________________________________________________________________________________
# marital (Dense)                 (None, 2)            18          dense_2[0][0]
# ==================================================================================================
# Total params: 24,116
# Trainable params: 24,116
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Train the model

# %%
model.fit(
    x=train_data,
    y=train_label,
    validation_data=(validation_data, validation_label),
    callbacks=[
        ROCCallback(
            training_data=(train_data, train_label),
            validation_data=(validation_data, validation_label),
            test_data=(test_data, test_label)
        )
    ],
    epochs=100
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 199523 samples, validate on 49881 samples
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 199523/199523 [==============================] - 25s 126us/step - loss: 0.7126 - income_loss: 0.3778 - marital_loss: 0.3348 - income_acc: 0.9345 - marital_acc: 0.9164 - val_loss: 0.6118 - val_income_loss: 0.3268 - val_marital_loss: 0.2850 - val_income_acc: 0.9378 - val_marital_acc: 0.9131
# ROC-AUC-income-Train: 0.7335 ROC-AUC-income-Validation: 0.7345 ROC-AUC-income-Test: 0.7419
# ROC-AUC-marital-Train: 0.98 ROC-AUC-marital-Validation: 0.9661 ROC-AUC-marital-Test: 0.967
# Epoch 2/100
# 199523/199523 [==============================] - 24s 120us/step - loss: 0.5167 - income_loss: 0.3161 - marital_loss: 0.2006 - income_acc: 0.9379 - marital_acc: 0.9424 - val_loss: 0.5736 - val_income_loss: 0.3207 - val_marital_loss: 0.2529 - val_income_acc: 0.9378 - val_marital_acc: 0.9201
# ROC-AUC-income-Train: 0.7489 ROC-AUC-income-Validation: 0.745 ROC-AUC-income-Test: 0.7534
# ROC-AUC-marital-Train: 0.9829 ROC-AUC-marital-Validation: 0.9698 ROC-AUC-marital-Test: 0.97
# Epoch 3/100
# 199523/199523 [==============================] - 23s 117us/step - loss: 0.4601 - income_loss: 0.3150 - marital_loss: 0.1451 - income_acc: 0.9379 - marital_acc: 0.9448 - val_loss: 0.6152 - val_income_loss: 0.3410 - val_marital_loss: 0.2742 - val_income_acc: 0.9378 - val_marital_acc: 0.8840
# ROC-AUC-income-Train: 0.7537 ROC-AUC-income-Validation: 0.7523 ROC-AUC-income-Test: 0.7554
# ROC-AUC-marital-Train: 0.9869 ROC-AUC-marital-Validation: 0.9685 ROC-AUC-marital-Test: 0.968
# Epoch 4/100
# 199523/199523 [==============================] - 23s 115us/step - loss: 0.3044 - income_loss: 0.1749 - marital_loss: 0.1295 - income_acc: 0.9382 - marital_acc: 0.9460 - val_loss: 0.3817 - val_income_loss: 0.1705 - val_marital_loss: 0.2112 - val_income_acc: 0.9378 - val_marital_acc: 0.9170
# ROC-AUC-income-Train: 0.9291 ROC-AUC-income-Validation: 0.9244 ROC-AUC-income-Test: 0.923
# ROC-AUC-marital-Train: 0.9902 ROC-AUC-marital-Validation: 0.9753 ROC-AUC-marital-Test: 0.9746
# Epoch 5/100
# 199523/199523 [==============================] - 23s 115us/step - loss: 0.2688 - income_loss: 0.1453 - marital_loss: 0.1236 - income_acc: 0.9379 - marital_acc: 0.9474 - val_loss: 0.3809 - val_income_loss: 0.1622 - val_marital_loss: 0.2187 - val_income_acc: 0.9378 - val_marital_acc: 0.9079
# ROC-AUC-income-Train: 0.921 ROC-AUC-income-Validation: 0.9167 ROC-AUC-income-Test: 0.917
# ROC-AUC-marital-Train: 0.9906 ROC-AUC-marital-Validation: 0.973 ROC-AUC-marital-Test: 0.9722
# Epoch 6/100
# 199523/199523 [==============================] - 23s 116us/step - loss: 0.2711 - income_loss: 0.1440 - marital_loss: 0.1272 - income_acc: 0.9379 - marital_acc: 0.9478 - val_loss: 0.4034 - val_income_loss: 0.1848 - val_marital_loss: 0.2186 - val_income_acc: 0.9378 - val_marital_acc: 0.9160
# ROC-AUC-income-Train: 0.9299 ROC-AUC-income-Validation: 0.9274 ROC-AUC-income-Test: 0.9251
# ROC-AUC-marital-Train: 0.9902 ROC-AUC-marital-Validation: 0.9745 ROC-AUC-marital-Test: 0.9737
# Epoch 7/100
# 199523/199523 [==============================] - 23s 115us/step - loss: 0.2665 - income_loss: 0.1428 - marital_loss: 0.1237 - income_acc: 0.9379 - marital_acc: 0.9482 - val_loss: 0.3822 - val_income_loss: 0.1536 - val_marital_loss: 0.2285 - val_income_acc: 0.9378 - val_marital_acc: 0.9017
# ROC-AUC-income-Train: 0.9243 ROC-AUC-income-Validation: 0.9218 ROC-AUC-income-Test: 0.9221
# ROC-AUC-marital-Train: 0.9923 ROC-AUC-marital-Validation: 0.9732 ROC-AUC-marital-Test: 0.9718
# Epoch 8/100
# 199523/199523 [==============================] - 25s 126us/step - loss: 0.2616 - income_loss: 0.1420 - marital_loss: 0.1196 - income_acc: 0.9379 - marital_acc: 0.9485 - val_loss: 0.4137 - val_income_loss: 0.1872 - val_marital_loss: 0.2265 - val_income_acc: 0.9378 - val_marital_acc: 0.9162
# ROC-AUC-income-Train: 0.9264 ROC-AUC-income-Validation: 0.922 ROC-AUC-income-Test: 0.9205
# ROC-AUC-marital-Train: 0.9906 ROC-AUC-marital-Validation: 0.9732 ROC-AUC-marital-Test: 0.9721
# Epoch 9/100
# 199523/199523 [==============================] - 24s 122us/step - loss: 0.2597 - income_loss: 0.1424 - marital_loss: 0.1173 - income_acc: 0.9378 - marital_acc: 0.9493 - val_loss: 0.4723 - val_income_loss: 0.1922 - val_marital_loss: 0.2800 - val_income_acc: 0.9378 - val_marital_acc: 0.8888
# ROC-AUC-income-Train: 0.9301 ROC-AUC-income-Validation: 0.9243 ROC-AUC-income-Test: 0.9233
# ROC-AUC-marital-Train: 0.9872 ROC-AUC-marital-Validation: 0.9621 ROC-AUC-marital-Test: 0.961
# Epoch 10/100
# 199523/199523 [==============================] - 24s 121us/step - loss: 0.2562 - income_loss: 0.1412 - marital_loss: 0.1151 - income_acc: 0.9379 - marital_acc: 0.9494 - val_loss: 0.3614 - val_income_loss: 0.1495 - val_marital_loss: 0.2119 - val_income_acc: 0.9405 - val_marital_acc: 0.9142
# ROC-AUC-income-Train: 0.9226 ROC-AUC-income-Validation: 0.9235 ROC-AUC-income-Test: 0.9239
# ROC-AUC-marital-Train: 0.9929 ROC-AUC-marital-Validation: 0.9737 ROC-AUC-marital-Test: 0.9727
# Epoch 11/100
# 199523/199523 [==============================] - 24s 118us/step - loss: 0.2612 - income_loss: 0.1403 - marital_loss: 0.1209 - income_acc: 0.9392 - marital_acc: 0.9518 - val_loss: 0.3962 - val_income_loss: 0.1768 - val_marital_loss: 0.2193 - val_income_acc: 0.9453 - val_marital_acc: 0.9120
# ROC-AUC-income-Train: 0.9384 ROC-AUC-income-Validation: 0.9345 ROC-AUC-income-Test: 0.9333
# ROC-AUC-marital-Train: 0.9923 ROC-AUC-marital-Validation: 0.9715 ROC-AUC-marital-Test: 0.9702
# Epoch 12/100
# 199523/199523 [==============================] - 24s 122us/step - loss: 0.2484 - income_loss: 0.1394 - marital_loss: 0.1091 - income_acc: 0.9396 - marital_acc: 0.9527 - val_loss: 0.4229 - val_income_loss: 0.1797 - val_marital_loss: 0.2432 - val_income_acc: 0.9378 - val_marital_acc: 0.8962
# ROC-AUC-income-Train: 0.9296 ROC-AUC-income-Validation: 0.9258 ROC-AUC-income-Test: 0.9252
# ROC-AUC-marital-Train: 0.9931 ROC-AUC-marital-Validation: 0.9682 ROC-AUC-marital-Test: 0.9672
# Epoch 13/100
# 199523/199523 [==============================] - 25s 128us/step - loss: 0.2543 - income_loss: 0.1392 - marital_loss: 0.1151 - income_acc: 0.9391 - marital_acc: 0.9525 - val_loss: 0.4257 - val_income_loss: 0.1854 - val_marital_loss: 0.2403 - val_income_acc: 0.9441 - val_marital_acc: 0.9108
# ROC-AUC-income-Train: 0.9388 ROC-AUC-income-Validation: 0.9349 ROC-AUC-income-Test: 0.9343
# ROC-AUC-marital-Train: 0.991 ROC-AUC-marital-Validation: 0.9683 ROC-AUC-marital-Test: 0.967
# Epoch 14/100
# 199523/199523 [==============================] - 24s 122us/step - loss: 0.2477 - income_loss: 0.1396 - marital_loss: 0.1081 - income_acc: 0.9388 - marital_acc: 0.9529 - val_loss: 0.4142 - val_income_loss: 0.1571 - val_marital_loss: 0.2571 - val_income_acc: 0.9378 - val_marital_acc: 0.9051
# ROC-AUC-income-Train: 0.9331 ROC-AUC-income-Validation: 0.93 ROC-AUC-income-Test: 0.9293
# ROC-AUC-marital-Train: 0.9921 ROC-AUC-marital-Validation: 0.9641 ROC-AUC-marital-Test: 0.9629
# Epoch 15/100
# 199523/199523 [==============================] - 24s 119us/step - loss: 0.2452 - income_loss: 0.1387 - marital_loss: 0.1065 - income_acc: 0.9386 - marital_acc: 0.9535 - val_loss: 0.4318 - val_income_loss: 0.1729 - val_marital_loss: 0.2590 - val_income_acc: 0.9441 - val_marital_acc: 0.8874
# ROC-AUC-income-Train: 0.935 ROC-AUC-income-Validation: 0.9308 ROC-AUC-income-Test: 0.9297
# ROC-AUC-marital-Train: 0.9909 ROC-AUC-marital-Validation: 0.965 ROC-AUC-marital-Test: 0.9637
# Epoch 16/100
# 199523/199523 [==============================] - 24s 118us/step - loss: 0.2467 - income_loss: 0.1368 - marital_loss: 0.1099 - income_acc: 0.9432 - marital_acc: 0.9540 - val_loss: 0.5092 - val_income_loss: 0.2071 - val_marital_loss: 0.3021 - val_income_acc: 0.9404 - val_marital_acc: 0.8796
# ROC-AUC-income-Train: 0.8954 ROC-AUC-income-Validation: 0.8865 ROC-AUC-income-Test: 0.8894
# ROC-AUC-marital-Train: 0.9893 ROC-AUC-marital-Validation: 0.9637 ROC-AUC-marital-Test: 0.9627
# Epoch 17/100
# 199523/199523 [==============================] - 24s 119us/step - loss: 0.2512 - income_loss: 0.1409 - marital_loss: 0.1103 - income_acc: 0.9439 - marital_acc: 0.9548 - val_loss: 0.4737 - val_income_loss: 0.1819 - val_marital_loss: 0.2918 - val_income_acc: 0.9353 - val_marital_acc: 0.8788
# ROC-AUC-income-Train: 0.9337 ROC-AUC-income-Validation: 0.928 ROC-AUC-income-Test: 0.9269
# ROC-AUC-marital-Train: 0.9929 ROC-AUC-marital-Validation: 0.9689 ROC-AUC-marital-Test: 0.9677
# Epoch 18/100
# 199523/199523 [==============================] - 24s 119us/step - loss: 0.2423 - income_loss: 0.1379 - marital_loss: 0.1044 - income_acc: 0.9417 - marital_acc: 0.9549 - val_loss: 0.4319 - val_income_loss: 0.1839 - val_marital_loss: 0.2480 - val_income_acc: 0.9442 - val_marital_acc: 0.9005
# ROC-AUC-income-Train: 0.9413 ROC-AUC-income-Validation: 0.9357 ROC-AUC-income-Test: 0.9355
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.969 ROC-AUC-marital-Test: 0.9677
# Epoch 19/100
# 199523/199523 [==============================] - 24s 121us/step - loss: 0.2415 - income_loss: 0.1374 - marital_loss: 0.1041 - income_acc: 0.9427 - marital_acc: 0.9549 - val_loss: 0.4197 - val_income_loss: 0.1758 - val_marital_loss: 0.2440 - val_income_acc: 0.9442 - val_marital_acc: 0.9007
# ROC-AUC-income-Train: 0.9404 ROC-AUC-income-Validation: 0.9351 ROC-AUC-income-Test: 0.9341
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.969 ROC-AUC-marital-Test: 0.9679
# Epoch 20/100
# 199523/199523 [==============================] - 26s 131us/step - loss: 0.2374 - income_loss: 0.1349 - marital_loss: 0.1025 - income_acc: 0.9457 - marital_acc: 0.9554 - val_loss: 0.4834 - val_income_loss: 0.2044 - val_marital_loss: 0.2790 - val_income_acc: 0.9390 - val_marital_acc: 0.8842
# ROC-AUC-income-Train: 0.9041 ROC-AUC-income-Validation: 0.892 ROC-AUC-income-Test: 0.8889
# ROC-AUC-marital-Train: 0.9927 ROC-AUC-marital-Validation: 0.9649 ROC-AUC-marital-Test: 0.9634
# Epoch 21/100
# 199523/199523 [==============================] - 23s 114us/step - loss: 0.2367 - income_loss: 0.1347 - marital_loss: 0.1020 - income_acc: 0.9463 - marital_acc: 0.9552 - val_loss: 0.4319 - val_income_loss: 0.1782 - val_marital_loss: 0.2536 - val_income_acc: 0.9441 - val_marital_acc: 0.9088
# ROC-AUC-income-Train: 0.9423 ROC-AUC-income-Validation: 0.9366 ROC-AUC-income-Test: 0.9358
# ROC-AUC-marital-Train: 0.9932 ROC-AUC-marital-Validation: 0.9684 ROC-AUC-marital-Test: 0.9672
# Epoch 22/100
# 199523/199523 [==============================] - 23s 113us/step - loss: 0.2407 - income_loss: 0.1354 - marital_loss: 0.1053 - income_acc: 0.9465 - marital_acc: 0.9557 - val_loss: 0.4472 - val_income_loss: 0.2009 - val_marital_loss: 0.2462 - val_income_acc: 0.9424 - val_marital_acc: 0.9081
# ROC-AUC-income-Train: 0.9368 ROC-AUC-income-Validation: 0.9316 ROC-AUC-income-Test: 0.9303
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9671 ROC-AUC-marital-Test: 0.9658
# Epoch 23/100
# 199523/199523 [==============================] - 22s 109us/step - loss: 0.2431 - income_loss: 0.1398 - marital_loss: 0.1033 - income_acc: 0.9467 - marital_acc: 0.9560 - val_loss: 0.4666 - val_income_loss: 0.2138 - val_marital_loss: 0.2528 - val_income_acc: 0.9430 - val_marital_acc: 0.8983
# ROC-AUC-income-Train: 0.9432 ROC-AUC-income-Validation: 0.9365 ROC-AUC-income-Test: 0.9356
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9684 ROC-AUC-marital-Test: 0.9673
# Epoch 24/100
# 199523/199523 [==============================] - 22s 110us/step - loss: 0.2529 - income_loss: 0.1500 - marital_loss: 0.1029 - income_acc: 0.9451 - marital_acc: 0.9546 - val_loss: 0.4305 - val_income_loss: 0.1771 - val_marital_loss: 0.2535 - val_income_acc: 0.9441 - val_marital_acc: 0.8984
# ROC-AUC-income-Train: 0.9315 ROC-AUC-income-Validation: 0.9149 ROC-AUC-income-Test: 0.9136
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9671 ROC-AUC-marital-Test: 0.9655
# Epoch 25/100
# 199523/199523 [==============================] - 22s 111us/step - loss: 0.2519 - income_loss: 0.1461 - marital_loss: 0.1058 - income_acc: 0.9439 - marital_acc: 0.9552 - val_loss: 0.4475 - val_income_loss: 0.1746 - val_marital_loss: 0.2730 - val_income_acc: 0.9444 - val_marital_acc: 0.8984
# ROC-AUC-income-Train: 0.9376 ROC-AUC-income-Validation: 0.9172 ROC-AUC-income-Test: 0.9185
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9647 ROC-AUC-marital-Test: 0.9634
# Epoch 26/100
# 199523/199523 [==============================] - 22s 109us/step - loss: 0.2500 - income_loss: 0.1477 - marital_loss: 0.1023 - income_acc: 0.9476 - marital_acc: 0.9557 - val_loss: 0.4306 - val_income_loss: 0.1653 - val_marital_loss: 0.2652 - val_income_acc: 0.9465 - val_marital_acc: 0.8874
# ROC-AUC-income-Train: 0.9245 ROC-AUC-income-Validation: 0.9016 ROC-AUC-income-Test: 0.9055
# ROC-AUC-marital-Train: 0.9925 ROC-AUC-marital-Validation: 0.9637 ROC-AUC-marital-Test: 0.9626
# Epoch 27/100
# 199523/199523 [==============================] - 22s 110us/step - loss: 0.2436 - income_loss: 0.1432 - marital_loss: 0.1003 - income_acc: 0.9457 - marital_acc: 0.9559 - val_loss: 0.4717 - val_income_loss: 0.1624 - val_marital_loss: 0.3093 - val_income_acc: 0.9437 - val_marital_acc: 0.8980
# ROC-AUC-income-Train: 0.9395 ROC-AUC-income-Validation: 0.9275 ROC-AUC-income-Test: 0.9284
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9619 ROC-AUC-marital-Test: 0.9604
# Epoch 28/100
# 199523/199523 [==============================] - 24s 118us/step - loss: 0.2436 - income_loss: 0.1433 - marital_loss: 0.1004 - income_acc: 0.9470 - marital_acc: 0.9558 - val_loss: 0.4558 - val_income_loss: 0.1649 - val_marital_loss: 0.2909 - val_income_acc: 0.9449 - val_marital_acc: 0.8954
# ROC-AUC-income-Train: 0.9349 ROC-AUC-income-Validation: 0.9151 ROC-AUC-income-Test: 0.9166
# ROC-AUC-marital-Train: 0.9927 ROC-AUC-marital-Validation: 0.9593 ROC-AUC-marital-Test: 0.9579
# Epoch 29/100
# 199523/199523 [==============================] - 24s 122us/step - loss: 0.2448 - income_loss: 0.1427 - marital_loss: 0.1021 - income_acc: 0.9481 - marital_acc: 0.9553 - val_loss: 0.4385 - val_income_loss: 0.1454 - val_marital_loss: 0.2931 - val_income_acc: 0.9477 - val_marital_acc: 0.8915
# ROC-AUC-income-Train: 0.9412 ROC-AUC-income-Validation: 0.934 ROC-AUC-income-Test: 0.9333
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9633 ROC-AUC-marital-Test: 0.9621
# Epoch 30/100
# 199523/199523 [==============================] - 23s 116us/step - loss: 0.2431 - income_loss: 0.1430 - marital_loss: 0.1001 - income_acc: 0.9463 - marital_acc: 0.9563 - val_loss: 0.4403 - val_income_loss: 0.1539 - val_marital_loss: 0.2864 - val_income_acc: 0.9434 - val_marital_acc: 0.8917
# ROC-AUC-income-Train: 0.9374 ROC-AUC-income-Validation: 0.9259 ROC-AUC-income-Test: 0.926
# ROC-AUC-marital-Train: 0.9931 ROC-AUC-marital-Validation: 0.9617 ROC-AUC-marital-Test: 0.9604
# Epoch 31/100
# 199523/199523 [==============================] - 22s 110us/step - loss: 0.2438 - income_loss: 0.1426 - marital_loss: 0.1012 - income_acc: 0.9467 - marital_acc: 0.9554 - val_loss: 0.4888 - val_income_loss: 0.1738 - val_marital_loss: 0.3150 - val_income_acc: 0.9425 - val_marital_acc: 0.8794
# ROC-AUC-income-Train: 0.8976 ROC-AUC-income-Validation: 0.9031 ROC-AUC-income-Test: 0.9014
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9593 ROC-AUC-marital-Test: 0.9578
# Epoch 32/100
# 199523/199523 [==============================] - 23s 114us/step - loss: 0.2436 - income_loss: 0.1420 - marital_loss: 0.1016 - income_acc: 0.9462 - marital_acc: 0.9563 - val_loss: 0.5137 - val_income_loss: 0.1438 - val_marital_loss: 0.3699 - val_income_acc: 0.9469 - val_marital_acc: 0.8529
# ROC-AUC-income-Train: 0.9366 ROC-AUC-income-Validation: 0.9322 ROC-AUC-income-Test: 0.9307
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9565 ROC-AUC-marital-Test: 0.955
# Epoch 33/100
# 199523/199523 [==============================] - 23s 114us/step - loss: 0.2449 - income_loss: 0.1441 - marital_loss: 0.1008 - income_acc: 0.9475 - marital_acc: 0.9564 - val_loss: 0.4493 - val_income_loss: 0.1383 - val_marital_loss: 0.3110 - val_income_acc: 0.9506 - val_marital_acc: 0.8753
# ROC-AUC-income-Train: 0.9407 ROC-AUC-income-Validation: 0.9377 ROC-AUC-income-Test: 0.9356
# ROC-AUC-marital-Train: 0.9932 ROC-AUC-marital-Validation: 0.9609 ROC-AUC-marital-Test: 0.9596
# Epoch 34/100
# 199523/199523 [==============================] - 22s 112us/step - loss: 0.2410 - income_loss: 0.1402 - marital_loss: 0.1008 - income_acc: 0.9472 - marital_acc: 0.9567 - val_loss: 0.4203 - val_income_loss: 0.1428 - val_marital_loss: 0.2775 - val_income_acc: 0.9437 - val_marital_acc: 0.8833
# ROC-AUC-income-Train: 0.9354 ROC-AUC-income-Validation: 0.9313 ROC-AUC-income-Test: 0.9304
# ROC-AUC-marital-Train: 0.9926 ROC-AUC-marital-Validation: 0.9584 ROC-AUC-marital-Test: 0.9571
# Epoch 35/100
# 199523/199523 [==============================] - 22s 112us/step - loss: 0.2402 - income_loss: 0.1412 - marital_loss: 0.0990 - income_acc: 0.9471 - marital_acc: 0.9564 - val_loss: 0.4457 - val_income_loss: 0.1375 - val_marital_loss: 0.3082 - val_income_acc: 0.9514 - val_marital_acc: 0.9048
# ROC-AUC-income-Train: 0.9412 ROC-AUC-income-Validation: 0.9374 ROC-AUC-income-Test: 0.9358
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.962 ROC-AUC-marital-Test: 0.9607
# Epoch 36/100
# 199523/199523 [==============================] - 22s 111us/step - loss: 0.2428 - income_loss: 0.1430 - marital_loss: 0.0998 - income_acc: 0.9468 - marital_acc: 0.9566 - val_loss: 0.4536 - val_income_loss: 0.1411 - val_marital_loss: 0.3125 - val_income_acc: 0.9476 - val_marital_acc: 0.8671
# ROC-AUC-income-Train: 0.9316 ROC-AUC-income-Validation: 0.9294 ROC-AUC-income-Test: 0.9298
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9575 ROC-AUC-marital-Test: 0.9561
# Epoch 37/100
# 199523/199523 [==============================] - 22s 110us/step - loss: 0.2405 - income_loss: 0.1411 - marital_loss: 0.0994 - income_acc: 0.9457 - marital_acc: 0.9563 - val_loss: 0.4589 - val_income_loss: 0.1395 - val_marital_loss: 0.3194 - val_income_acc: 0.9515 - val_marital_acc: 0.8803
# ROC-AUC-income-Train: 0.9405 ROC-AUC-income-Validation: 0.9354 ROC-AUC-income-Test: 0.9335
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9608 ROC-AUC-marital-Test: 0.9592
# Epoch 38/100
# 199523/199523 [==============================] - 22s 110us/step - loss: 0.2400 - income_loss: 0.1403 - marital_loss: 0.0997 - income_acc: 0.9465 - marital_acc: 0.9563 - val_loss: 0.4229 - val_income_loss: 0.1368 - val_marital_loss: 0.2861 - val_income_acc: 0.9493 - val_marital_acc: 0.8965
# ROC-AUC-income-Train: 0.936 ROC-AUC-income-Validation: 0.9341 ROC-AUC-income-Test: 0.932
# ROC-AUC-marital-Train: 0.9929 ROC-AUC-marital-Validation: 0.9611 ROC-AUC-marital-Test: 0.9594
# Epoch 39/100
# 199523/199523 [==============================] - 22s 112us/step - loss: 0.2393 - income_loss: 0.1408 - marital_loss: 0.0985 - income_acc: 0.9484 - marital_acc: 0.9569 - val_loss: 0.4534 - val_income_loss: 0.1395 - val_marital_loss: 0.3139 - val_income_acc: 0.9491 - val_marital_acc: 0.8861
# ROC-AUC-income-Train: 0.9313 ROC-AUC-income-Validation: 0.9295 ROC-AUC-income-Test: 0.9276
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9608 ROC-AUC-marital-Test: 0.9593
# Epoch 40/100
# 199523/199523 [==============================] - 23s 113us/step - loss: 0.2421 - income_loss: 0.1439 - marital_loss: 0.0983 - income_acc: 0.9483 - marital_acc: 0.9563 - val_loss: 0.5211 - val_income_loss: 0.1717 - val_marital_loss: 0.3494 - val_income_acc: 0.9457 - val_marital_acc: 0.8677
# ROC-AUC-income-Train: 0.8763 ROC-AUC-income-Validation: 0.8776 ROC-AUC-income-Test: 0.8797
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9558 ROC-AUC-marital-Test: 0.9544
# Epoch 41/100
# 199523/199523 [==============================] - 23s 117us/step - loss: 0.2421 - income_loss: 0.1400 - marital_loss: 0.1021 - income_acc: 0.9482 - marital_acc: 0.9563 - val_loss: 0.4089 - val_income_loss: 0.1354 - val_marital_loss: 0.2736 - val_income_acc: 0.9510 - val_marital_acc: 0.8988
# ROC-AUC-income-Train: 0.9421 ROC-AUC-income-Validation: 0.939 ROC-AUC-income-Test: 0.9364
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9643 ROC-AUC-marital-Test: 0.9629
# Epoch 42/100
# 199523/199523 [==============================] - 22s 112us/step - loss: 0.2423 - income_loss: 0.1408 - marital_loss: 0.1015 - income_acc: 0.9485 - marital_acc: 0.9570 - val_loss: 0.4168 - val_income_loss: 0.1388 - val_marital_loss: 0.2779 - val_income_acc: 0.9485 - val_marital_acc: 0.9004
# ROC-AUC-income-Train: 0.9334 ROC-AUC-income-Validation: 0.9308 ROC-AUC-income-Test: 0.9277
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9617 ROC-AUC-marital-Test: 0.9603
# Epoch 43/100
# 199523/199523 [==============================] - 22s 111us/step - loss: 0.2399 - income_loss: 0.1417 - marital_loss: 0.0981 - income_acc: 0.9481 - marital_acc: 0.9568 - val_loss: 0.4423 - val_income_loss: 0.1354 - val_marital_loss: 0.3069 - val_income_acc: 0.9507 - val_marital_acc: 0.8835
# ROC-AUC-income-Train: 0.9411 ROC-AUC-income-Validation: 0.9383 ROC-AUC-income-Test: 0.9363
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9588 ROC-AUC-marital-Test: 0.9573
# Epoch 44/100
# 199523/199523 [==============================] - 22s 112us/step - loss: 0.2424 - income_loss: 0.1402 - marital_loss: 0.1022 - income_acc: 0.9479 - marital_acc: 0.9572 - val_loss: 0.4585 - val_income_loss: 0.1359 - val_marital_loss: 0.3225 - val_income_acc: 0.9489 - val_marital_acc: 0.8809
# ROC-AUC-income-Train: 0.9384 ROC-AUC-income-Validation: 0.9364 ROC-AUC-income-Test: 0.9334
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9599 ROC-AUC-marital-Test: 0.9583
# Epoch 45/100
# 199523/199523 [==============================] - 22s 111us/step - loss: 0.2401 - income_loss: 0.1411 - marital_loss: 0.0990 - income_acc: 0.9490 - marital_acc: 0.9572 - val_loss: 0.4471 - val_income_loss: 0.1438 - val_marital_loss: 0.3033 - val_income_acc: 0.9495 - val_marital_acc: 0.8859
# ROC-AUC-income-Train: 0.9409 ROC-AUC-income-Validation: 0.9373 ROC-AUC-income-Test: 0.9356
# ROC-AUC-marital-Train: 0.991 ROC-AUC-marital-Validation: 0.9579 ROC-AUC-marital-Test: 0.9566
# Epoch 46/100
# 199523/199523 [==============================] - 22s 111us/step - loss: 0.2452 - income_loss: 0.1432 - marital_loss: 0.1020 - income_acc: 0.9479 - marital_acc: 0.9572 - val_loss: 0.4011 - val_income_loss: 0.1390 - val_marital_loss: 0.2621 - val_income_acc: 0.9520 - val_marital_acc: 0.9023
# ROC-AUC-income-Train: 0.937 ROC-AUC-income-Validation: 0.9307 ROC-AUC-income-Test: 0.9293
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9642 ROC-AUC-marital-Test: 0.9627
# Epoch 47/100
# 199523/199523 [==============================] - 22s 112us/step - loss: 0.2380 - income_loss: 0.1411 - marital_loss: 0.0969 - income_acc: 0.9485 - marital_acc: 0.9578 - val_loss: 0.4550 - val_income_loss: 0.1623 - val_marital_loss: 0.2927 - val_income_acc: 0.9430 - val_marital_acc: 0.9001
# ROC-AUC-income-Train: 0.9051 ROC-AUC-income-Validation: 0.9025 ROC-AUC-income-Test: 0.9022
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9628 ROC-AUC-marital-Test: 0.9612
# Epoch 48/100
# 199523/199523 [==============================] - 22s 111us/step - loss: 0.2389 - income_loss: 0.1398 - marital_loss: 0.0991 - income_acc: 0.9483 - marital_acc: 0.9574 - val_loss: 0.4252 - val_income_loss: 0.1405 - val_marital_loss: 0.2848 - val_income_acc: 0.9492 - val_marital_acc: 0.9013
# ROC-AUC-income-Train: 0.9403 ROC-AUC-income-Validation: 0.9372 ROC-AUC-income-Test: 0.936
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9619 ROC-AUC-marital-Test: 0.9605
# Epoch 49/100
# 199523/199523 [==============================] - 22s 111us/step - loss: 0.2404 - income_loss: 0.1408 - marital_loss: 0.0997 - income_acc: 0.9463 - marital_acc: 0.9575 - val_loss: 0.4217 - val_income_loss: 0.1454 - val_marital_loss: 0.2762 - val_income_acc: 0.9425 - val_marital_acc: 0.8974
# ROC-AUC-income-Train: 0.9334 ROC-AUC-income-Validation: 0.9279 ROC-AUC-income-Test: 0.9281
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9615 ROC-AUC-marital-Test: 0.96
# Epoch 50/100
# 199523/199523 [==============================] - 24s 118us/step - loss: 0.2410 - income_loss: 0.1396 - marital_loss: 0.1013 - income_acc: 0.9469 - marital_acc: 0.9575 - val_loss: 0.4274 - val_income_loss: 0.1375 - val_marital_loss: 0.2899 - val_income_acc: 0.9498 - val_marital_acc: 0.8966
# ROC-AUC-income-Train: 0.9387 ROC-AUC-income-Validation: 0.9354 ROC-AUC-income-Test: 0.9332
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9637 ROC-AUC-marital-Test: 0.9626
# Epoch 51/100
# 199523/199523 [==============================] - 22s 111us/step - loss: 0.2418 - income_loss: 0.1431 - marital_loss: 0.0987 - income_acc: 0.9479 - marital_acc: 0.9575 - val_loss: 0.4392 - val_income_loss: 0.1453 - val_marital_loss: 0.2939 - val_income_acc: 0.9445 - val_marital_acc: 0.8841
# ROC-AUC-income-Train: 0.9282 ROC-AUC-income-Validation: 0.9257 ROC-AUC-income-Test: 0.9231
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9614 ROC-AUC-marital-Test: 0.9599
# Epoch 52/100
# 199523/199523 [==============================] - 23s 113us/step - loss: 0.2389 - income_loss: 0.1404 - marital_loss: 0.0985 - income_acc: 0.9472 - marital_acc: 0.9572 - val_loss: 0.4242 - val_income_loss: 0.1386 - val_marital_loss: 0.2856 - val_income_acc: 0.9501 - val_marital_acc: 0.8924
# ROC-AUC-income-Train: 0.9327 ROC-AUC-income-Validation: 0.9314 ROC-AUC-income-Test: 0.9286
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9617 ROC-AUC-marital-Test: 0.9602
# Epoch 53/100
# 199523/199523 [==============================] - 22s 110us/step - loss: 0.2385 - income_loss: 0.1400 - marital_loss: 0.0985 - income_acc: 0.9474 - marital_acc: 0.9576 - val_loss: 0.4422 - val_income_loss: 0.1355 - val_marital_loss: 0.3068 - val_income_acc: 0.9508 - val_marital_acc: 0.8797
# ROC-AUC-income-Train: 0.9402 ROC-AUC-income-Validation: 0.938 ROC-AUC-income-Test: 0.9358
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9577 ROC-AUC-marital-Test: 0.956
# Epoch 54/100
# 199523/199523 [==============================] - 22s 112us/step - loss: 0.2439 - income_loss: 0.1452 - marital_loss: 0.0986 - income_acc: 0.9473 - marital_acc: 0.9569 - val_loss: 0.4190 - val_income_loss: 0.1382 - val_marital_loss: 0.2809 - val_income_acc: 0.9507 - val_marital_acc: 0.8929
# ROC-AUC-income-Train: 0.94 ROC-AUC-income-Validation: 0.936 ROC-AUC-income-Test: 0.9338
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9605 ROC-AUC-marital-Test: 0.959
# Epoch 55/100
# 199523/199523 [==============================] - 22s 112us/step - loss: 0.2403 - income_loss: 0.1400 - marital_loss: 0.1002 - income_acc: 0.9478 - marital_acc: 0.9574 - val_loss: 0.4539 - val_income_loss: 0.1843 - val_marital_loss: 0.2696 - val_income_acc: 0.9040 - val_marital_acc: 0.9093
# ROC-AUC-income-Train: 0.9132 ROC-AUC-income-Validation: 0.9139 ROC-AUC-income-Test: 0.9141
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9656 ROC-AUC-marital-Test: 0.9643
# Epoch 56/100
# 199523/199523 [==============================] - 23s 114us/step - loss: 0.2472 - income_loss: 0.1431 - marital_loss: 0.1040 - income_acc: 0.9491 - marital_acc: 0.9575 - val_loss: 0.4617 - val_income_loss: 0.1370 - val_marital_loss: 0.3247 - val_income_acc: 0.9508 - val_marital_acc: 0.8695
# ROC-AUC-income-Train: 0.9427 ROC-AUC-income-Validation: 0.9374 ROC-AUC-income-Test: 0.9356
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9606 ROC-AUC-marital-Test: 0.9592
# Epoch 57/100
# 199523/199523 [==============================] - 22s 113us/step - loss: 0.2458 - income_loss: 0.1418 - marital_loss: 0.1040 - income_acc: 0.9485 - marital_acc: 0.9576 - val_loss: 0.4255 - val_income_loss: 0.1450 - val_marital_loss: 0.2806 - val_income_acc: 0.9496 - val_marital_acc: 0.8918
# ROC-AUC-income-Train: 0.9407 ROC-AUC-income-Validation: 0.9358 ROC-AUC-income-Test: 0.9337
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9636 ROC-AUC-marital-Test: 0.9622
# Epoch 58/100
# 199523/199523 [==============================] - 23s 114us/step - loss: 0.2352 - income_loss: 0.1388 - marital_loss: 0.0964 - income_acc: 0.9503 - marital_acc: 0.9576 - val_loss: 0.4392 - val_income_loss: 0.1476 - val_marital_loss: 0.2916 - val_income_acc: 0.9472 - val_marital_acc: 0.8912
# ROC-AUC-income-Train: 0.9285 ROC-AUC-income-Validation: 0.9222 ROC-AUC-income-Test: 0.923
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9616 ROC-AUC-marital-Test: 0.96
# Epoch 59/100
# 199523/199523 [==============================] - 22s 112us/step - loss: 0.2370 - income_loss: 0.1382 - marital_loss: 0.0989 - income_acc: 0.9490 - marital_acc: 0.9573 - val_loss: 0.4648 - val_income_loss: 0.1367 - val_marital_loss: 0.3281 - val_income_acc: 0.9500 - val_marital_acc: 0.8719
# ROC-AUC-income-Train: 0.9417 ROC-AUC-income-Validation: 0.9384 ROC-AUC-income-Test: 0.9364
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9588 ROC-AUC-marital-Test: 0.9571
# Epoch 60/100
# 199523/199523 [==============================] - 23s 114us/step - loss: 0.2375 - income_loss: 0.1408 - marital_loss: 0.0967 - income_acc: 0.9470 - marital_acc: 0.9573 - val_loss: 0.4666 - val_income_loss: 0.1452 - val_marital_loss: 0.3214 - val_income_acc: 0.9424 - val_marital_acc: 0.8779
# ROC-AUC-income-Train: 0.9351 ROC-AUC-income-Validation: 0.9304 ROC-AUC-income-Test: 0.9287
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9561 ROC-AUC-marital-Test: 0.955
# Epoch 61/100
# 199523/199523 [==============================] - 22s 112us/step - loss: 0.2343 - income_loss: 0.1369 - marital_loss: 0.0974 - income_acc: 0.9497 - marital_acc: 0.9581 - val_loss: 0.4763 - val_income_loss: 0.1361 - val_marital_loss: 0.3402 - val_income_acc: 0.9517 - val_marital_acc: 0.8858
# ROC-AUC-income-Train: 0.9417 ROC-AUC-income-Validation: 0.9376 ROC-AUC-income-Test: 0.9356
# ROC-AUC-marital-Train: 0.9923 ROC-AUC-marital-Validation: 0.9553 ROC-AUC-marital-Test: 0.9539
# Epoch 62/100
# 199523/199523 [==============================] - 23s 116us/step - loss: 0.2402 - income_loss: 0.1431 - marital_loss: 0.0971 - income_acc: 0.9488 - marital_acc: 0.9575 - val_loss: 0.4785 - val_income_loss: 0.1366 - val_marital_loss: 0.3419 - val_income_acc: 0.9513 - val_marital_acc: 0.8660
# ROC-AUC-income-Train: 0.9413 ROC-AUC-income-Validation: 0.9362 ROC-AUC-income-Test: 0.9345
# ROC-AUC-marital-Train: 0.9928 ROC-AUC-marital-Validation: 0.9561 ROC-AUC-marital-Test: 0.9545
# Epoch 63/100
# 199523/199523 [==============================] - 22s 112us/step - loss: 0.2363 - income_loss: 0.1393 - marital_loss: 0.0970 - income_acc: 0.9499 - marital_acc: 0.9571 - val_loss: 0.4477 - val_income_loss: 0.1389 - val_marital_loss: 0.3089 - val_income_acc: 0.9511 - val_marital_acc: 0.8940
# ROC-AUC-income-Train: 0.9347 ROC-AUC-income-Validation: 0.9334 ROC-AUC-income-Test: 0.9308
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9593 ROC-AUC-marital-Test: 0.958
# Epoch 64/100
# 199523/199523 [==============================] - 22s 112us/step - loss: 0.2387 - income_loss: 0.1397 - marital_loss: 0.0989 - income_acc: 0.9477 - marital_acc: 0.9573 - val_loss: 0.4178 - val_income_loss: 0.1362 - val_marital_loss: 0.2815 - val_income_acc: 0.9517 - val_marital_acc: 0.9005
# ROC-AUC-income-Train: 0.9427 ROC-AUC-income-Validation: 0.9382 ROC-AUC-income-Test: 0.9363
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9644 ROC-AUC-marital-Test: 0.963
# Epoch 65/100
# 199523/199523 [==============================] - 22s 112us/step - loss: 0.2370 - income_loss: 0.1394 - marital_loss: 0.0976 - income_acc: 0.9485 - marital_acc: 0.9574 - val_loss: 0.3998 - val_income_loss: 0.1376 - val_marital_loss: 0.2622 - val_income_acc: 0.9519 - val_marital_acc: 0.9069
# ROC-AUC-income-Train: 0.9371 ROC-AUC-income-Validation: 0.9346 ROC-AUC-income-Test: 0.9318
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9662 ROC-AUC-marital-Test: 0.9649
# Epoch 66/100
# 199523/199523 [==============================] - 23s 113us/step - loss: 0.2386 - income_loss: 0.1412 - marital_loss: 0.0974 - income_acc: 0.9466 - marital_acc: 0.9572 - val_loss: 0.4460 - val_income_loss: 0.1460 - val_marital_loss: 0.3000 - val_income_acc: 0.9402 - val_marital_acc: 0.9034
# ROC-AUC-income-Train: 0.9355 ROC-AUC-income-Validation: 0.934 ROC-AUC-income-Test: 0.9335
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9615 ROC-AUC-marital-Test: 0.9599
# Epoch 67/100
# 199523/199523 [==============================] - 23s 114us/step - loss: 0.2401 - income_loss: 0.1429 - marital_loss: 0.0972 - income_acc: 0.9438 - marital_acc: 0.9577 - val_loss: 0.4483 - val_income_loss: 0.1696 - val_marital_loss: 0.2787 - val_income_acc: 0.9440 - val_marital_acc: 0.8946
# ROC-AUC-income-Train: 0.9076 ROC-AUC-income-Validation: 0.8931 ROC-AUC-income-Test: 0.8939
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9636 ROC-AUC-marital-Test: 0.9623
# Epoch 68/100
# 199523/199523 [==============================] - 23s 114us/step - loss: 0.2369 - income_loss: 0.1416 - marital_loss: 0.0952 - income_acc: 0.9466 - marital_acc: 0.9584 - val_loss: 0.4150 - val_income_loss: 0.1380 - val_marital_loss: 0.2770 - val_income_acc: 0.9494 - val_marital_acc: 0.9006
# ROC-AUC-income-Train: 0.9358 ROC-AUC-income-Validation: 0.9343 ROC-AUC-income-Test: 0.9323
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9616 ROC-AUC-marital-Test: 0.96
# Epoch 69/100
# 199523/199523 [==============================] - 23s 114us/step - loss: 0.2386 - income_loss: 0.1423 - marital_loss: 0.0962 - income_acc: 0.9447 - marital_acc: 0.9582 - val_loss: 0.4303 - val_income_loss: 0.1576 - val_marital_loss: 0.2727 - val_income_acc: 0.9436 - val_marital_acc: 0.8971
# ROC-AUC-income-Train: 0.9116 ROC-AUC-income-Validation: 0.9118 ROC-AUC-income-Test: 0.9121
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9615 ROC-AUC-marital-Test: 0.96
# Epoch 70/100
# 199523/199523 [==============================] - 23s 113us/step - loss: 0.2362 - income_loss: 0.1404 - marital_loss: 0.0958 - income_acc: 0.9464 - marital_acc: 0.9582 - val_loss: 0.4386 - val_income_loss: 0.1366 - val_marital_loss: 0.3019 - val_income_acc: 0.9508 - val_marital_acc: 0.8817
# ROC-AUC-income-Train: 0.9419 ROC-AUC-income-Validation: 0.9376 ROC-AUC-income-Test: 0.9359
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9596 ROC-AUC-marital-Test: 0.9582
# Epoch 71/100
# 199523/199523 [==============================] - 25s 126us/step - loss: 0.2359 - income_loss: 0.1398 - marital_loss: 0.0961 - income_acc: 0.9478 - marital_acc: 0.9577 - val_loss: 0.4381 - val_income_loss: 0.1479 - val_marital_loss: 0.2902 - val_income_acc: 0.9482 - val_marital_acc: 0.8982
# ROC-AUC-income-Train: 0.9413 ROC-AUC-income-Validation: 0.9344 ROC-AUC-income-Test: 0.9326
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9631 ROC-AUC-marital-Test: 0.9616
# Epoch 72/100
# 199523/199523 [==============================] - 24s 122us/step - loss: 0.2358 - income_loss: 0.1398 - marital_loss: 0.0961 - income_acc: 0.9484 - marital_acc: 0.9580 - val_loss: 0.4390 - val_income_loss: 0.1402 - val_marital_loss: 0.2988 - val_income_acc: 0.9471 - val_marital_acc: 0.8864
# ROC-AUC-income-Train: 0.9382 ROC-AUC-income-Validation: 0.9341 ROC-AUC-income-Test: 0.9338
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9625 ROC-AUC-marital-Test: 0.961
# Epoch 73/100
# 199523/199523 [==============================] - 24s 122us/step - loss: 0.2365 - income_loss: 0.1387 - marital_loss: 0.0978 - income_acc: 0.9489 - marital_acc: 0.9580 - val_loss: 0.4170 - val_income_loss: 0.1490 - val_marital_loss: 0.2679 - val_income_acc: 0.9478 - val_marital_acc: 0.9065
# ROC-AUC-income-Train: 0.934 ROC-AUC-income-Validation: 0.9245 ROC-AUC-income-Test: 0.924
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9642 ROC-AUC-marital-Test: 0.9629
# Epoch 74/100
# 199523/199523 [==============================] - 24s 120us/step - loss: 0.2382 - income_loss: 0.1419 - marital_loss: 0.0963 - income_acc: 0.9459 - marital_acc: 0.9588 - val_loss: 0.4230 - val_income_loss: 0.1452 - val_marital_loss: 0.2778 - val_income_acc: 0.9485 - val_marital_acc: 0.9005
# ROC-AUC-income-Train: 0.9392 ROC-AUC-income-Validation: 0.9318 ROC-AUC-income-Test: 0.9301
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9624 ROC-AUC-marital-Test: 0.9611
# Epoch 75/100
# 199523/199523 [==============================] - 25s 123us/step - loss: 0.2375 - income_loss: 0.1414 - marital_loss: 0.0961 - income_acc: 0.9489 - marital_acc: 0.9580 - val_loss: 0.4236 - val_income_loss: 0.1565 - val_marital_loss: 0.2671 - val_income_acc: 0.9432 - val_marital_acc: 0.9057
# ROC-AUC-income-Train: 0.9298 ROC-AUC-income-Validation: 0.9262 ROC-AUC-income-Test: 0.924
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.964 ROC-AUC-marital-Test: 0.9629
# Epoch 76/100
# 199523/199523 [==============================] - 24s 121us/step - loss: 0.2396 - income_loss: 0.1411 - marital_loss: 0.0985 - income_acc: 0.9489 - marital_acc: 0.9582 - val_loss: 0.4155 - val_income_loss: 0.1601 - val_marital_loss: 0.2554 - val_income_acc: 0.9464 - val_marital_acc: 0.9073
# ROC-AUC-income-Train: 0.9072 ROC-AUC-income-Validation: 0.9011 ROC-AUC-income-Test: 0.8994
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9648 ROC-AUC-marital-Test: 0.9635
# Epoch 77/100
# 199523/199523 [==============================] - 24s 121us/step - loss: 0.2390 - income_loss: 0.1418 - marital_loss: 0.0973 - income_acc: 0.9488 - marital_acc: 0.9576 - val_loss: 0.4681 - val_income_loss: 0.1447 - val_marital_loss: 0.3234 - val_income_acc: 0.9491 - val_marital_acc: 0.8800
# ROC-AUC-income-Train: 0.9391 ROC-AUC-income-Validation: 0.9334 ROC-AUC-income-Test: 0.9316
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9602 ROC-AUC-marital-Test: 0.9588
# Epoch 78/100
# 199523/199523 [==============================] - 24s 121us/step - loss: 0.2373 - income_loss: 0.1397 - marital_loss: 0.0975 - income_acc: 0.9501 - marital_acc: 0.9574 - val_loss: 0.4126 - val_income_loss: 0.1386 - val_marital_loss: 0.2740 - val_income_acc: 0.9507 - val_marital_acc: 0.8988
# ROC-AUC-income-Train: 0.9412 ROC-AUC-income-Validation: 0.9355 ROC-AUC-income-Test: 0.9342
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9646 ROC-AUC-marital-Test: 0.9632
# Epoch 79/100
# 199523/199523 [==============================] - 24s 122us/step - loss: 0.2338 - income_loss: 0.1384 - marital_loss: 0.0954 - income_acc: 0.9498 - marital_acc: 0.9579 - val_loss: 0.4041 - val_income_loss: 0.1440 - val_marital_loss: 0.2601 - val_income_acc: 0.9497 - val_marital_acc: 0.9079
# ROC-AUC-income-Train: 0.9359 ROC-AUC-income-Validation: 0.9321 ROC-AUC-income-Test: 0.9312
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9677 ROC-AUC-marital-Test: 0.9665
# Epoch 80/100
# 199523/199523 [==============================] - 24s 119us/step - loss: 0.2362 - income_loss: 0.1403 - marital_loss: 0.0958 - income_acc: 0.9495 - marital_acc: 0.9577 - val_loss: 0.4177 - val_income_loss: 0.1465 - val_marital_loss: 0.2712 - val_income_acc: 0.9499 - val_marital_acc: 0.9093
# ROC-AUC-income-Train: 0.9323 ROC-AUC-income-Validation: 0.9296 ROC-AUC-income-Test: 0.9283
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.966 ROC-AUC-marital-Test: 0.9646
# Epoch 81/100
# 199523/199523 [==============================] - 24s 119us/step - loss: 0.2370 - income_loss: 0.1399 - marital_loss: 0.0970 - income_acc: 0.9486 - marital_acc: 0.9586 - val_loss: 0.4592 - val_income_loss: 0.1555 - val_marital_loss: 0.3037 - val_income_acc: 0.9453 - val_marital_acc: 0.8989
# ROC-AUC-income-Train: 0.9152 ROC-AUC-income-Validation: 0.9063 ROC-AUC-income-Test: 0.9055
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9618 ROC-AUC-marital-Test: 0.9603
# Epoch 82/100
# 199523/199523 [==============================] - 23s 116us/step - loss: 0.2374 - income_loss: 0.1425 - marital_loss: 0.0948 - income_acc: 0.9490 - marital_acc: 0.9587 - val_loss: 0.4420 - val_income_loss: 0.1423 - val_marital_loss: 0.2997 - val_income_acc: 0.9498 - val_marital_acc: 0.8998
# ROC-AUC-income-Train: 0.9415 ROC-AUC-income-Validation: 0.9334 ROC-AUC-income-Test: 0.9325
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9603 ROC-AUC-marital-Test: 0.9588
# Epoch 83/100
# 199523/199523 [==============================] - 24s 121us/step - loss: 0.2345 - income_loss: 0.1393 - marital_loss: 0.0952 - income_acc: 0.9493 - marital_acc: 0.9584 - val_loss: 0.4215 - val_income_loss: 0.1440 - val_marital_loss: 0.2775 - val_income_acc: 0.9500 - val_marital_acc: 0.9039
# ROC-AUC-income-Train: 0.9386 ROC-AUC-income-Validation: 0.9301 ROC-AUC-income-Test: 0.9304
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9653 ROC-AUC-marital-Test: 0.9644
# Epoch 84/100
# 199523/199523 [==============================] - 23s 117us/step - loss: 0.2358 - income_loss: 0.1401 - marital_loss: 0.0957 - income_acc: 0.9483 - marital_acc: 0.9581 - val_loss: 0.4096 - val_income_loss: 0.1445 - val_marital_loss: 0.2651 - val_income_acc: 0.9475 - val_marital_acc: 0.9046
# ROC-AUC-income-Train: 0.9393 ROC-AUC-income-Validation: 0.9317 ROC-AUC-income-Test: 0.9304
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9661 ROC-AUC-marital-Test: 0.9649
# Epoch 85/100
# 199523/199523 [==============================] - 23s 117us/step - loss: 0.2357 - income_loss: 0.1399 - marital_loss: 0.0959 - income_acc: 0.9483 - marital_acc: 0.9582 - val_loss: 0.4321 - val_income_loss: 0.1759 - val_marital_loss: 0.2563 - val_income_acc: 0.9447 - val_marital_acc: 0.9057
# ROC-AUC-income-Train: 0.9207 ROC-AUC-income-Validation: 0.9008 ROC-AUC-income-Test: 0.9055
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9681 ROC-AUC-marital-Test: 0.9668
# Epoch 86/100
# 199523/199523 [==============================] - 23s 117us/step - loss: 0.2379 - income_loss: 0.1420 - marital_loss: 0.0959 - income_acc: 0.9482 - marital_acc: 0.9585 - val_loss: 0.4177 - val_income_loss: 0.1417 - val_marital_loss: 0.2759 - val_income_acc: 0.9503 - val_marital_acc: 0.9063
# ROC-AUC-income-Train: 0.9415 ROC-AUC-income-Validation: 0.9311 ROC-AUC-income-Test: 0.93
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9649 ROC-AUC-marital-Test: 0.9636
# Epoch 87/100
# 199523/199523 [==============================] - 23s 117us/step - loss: 0.2356 - income_loss: 0.1401 - marital_loss: 0.0955 - income_acc: 0.9487 - marital_acc: 0.9581 - val_loss: 0.4056 - val_income_loss: 0.1376 - val_marital_loss: 0.2680 - val_income_acc: 0.9508 - val_marital_acc: 0.9051
# ROC-AUC-income-Train: 0.9418 ROC-AUC-income-Validation: 0.9358 ROC-AUC-income-Test: 0.9343
# ROC-AUC-marital-Train: 0.9944 ROC-AUC-marital-Validation: 0.9642 ROC-AUC-marital-Test: 0.9628
# Epoch 88/100
# 199523/199523 [==============================] - 24s 119us/step - loss: 0.2358 - income_loss: 0.1396 - marital_loss: 0.0961 - income_acc: 0.9479 - marital_acc: 0.9586 - val_loss: 0.4325 - val_income_loss: 0.1468 - val_marital_loss: 0.2857 - val_income_acc: 0.9492 - val_marital_acc: 0.9073
# ROC-AUC-income-Train: 0.9422 ROC-AUC-income-Validation: 0.9326 ROC-AUC-income-Test: 0.9318
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9676 ROC-AUC-marital-Test: 0.9663
# Epoch 89/100
# 199523/199523 [==============================] - 24s 118us/step - loss: 0.2345 - income_loss: 0.1392 - marital_loss: 0.0953 - income_acc: 0.9497 - marital_acc: 0.9579 - val_loss: 0.3963 - val_income_loss: 0.1408 - val_marital_loss: 0.2555 - val_income_acc: 0.9506 - val_marital_acc: 0.9049
# ROC-AUC-income-Train: 0.9432 ROC-AUC-income-Validation: 0.9353 ROC-AUC-income-Test: 0.9343
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9653 ROC-AUC-marital-Test: 0.9641
# Epoch 90/100
# 199523/199523 [==============================] - 24s 122us/step - loss: 0.2335 - income_loss: 0.1375 - marital_loss: 0.0960 - income_acc: 0.9504 - marital_acc: 0.9573 - val_loss: 0.4119 - val_income_loss: 0.1379 - val_marital_loss: 0.2740 - val_income_acc: 0.9496 - val_marital_acc: 0.9074
# ROC-AUC-income-Train: 0.9421 ROC-AUC-income-Validation: 0.9369 ROC-AUC-income-Test: 0.9351
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9679 ROC-AUC-marital-Test: 0.9665
# Epoch 91/100
# 199523/199523 [==============================] - 26s 130us/step - loss: 0.2352 - income_loss: 0.1383 - marital_loss: 0.0969 - income_acc: 0.9503 - marital_acc: 0.9571 - val_loss: 0.4146 - val_income_loss: 0.1424 - val_marital_loss: 0.2721 - val_income_acc: 0.9503 - val_marital_acc: 0.9051
# ROC-AUC-income-Train: 0.9386 ROC-AUC-income-Validation: 0.9355 ROC-AUC-income-Test: 0.9339
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9641 ROC-AUC-marital-Test: 0.963
# Epoch 92/100
# 199523/199523 [==============================] - 24s 121us/step - loss: 0.2321 - income_loss: 0.1367 - marital_loss: 0.0954 - income_acc: 0.9501 - marital_acc: 0.9576 - val_loss: 0.3936 - val_income_loss: 0.1363 - val_marital_loss: 0.2573 - val_income_acc: 0.9516 - val_marital_acc: 0.9071
# ROC-AUC-income-Train: 0.9432 ROC-AUC-income-Validation: 0.9377 ROC-AUC-income-Test: 0.9368
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9691 ROC-AUC-marital-Test: 0.9676
# Epoch 93/100
# 199523/199523 [==============================] - 25s 123us/step - loss: 0.2342 - income_loss: 0.1388 - marital_loss: 0.0954 - income_acc: 0.9478 - marital_acc: 0.9575 - val_loss: 0.4250 - val_income_loss: 0.1493 - val_marital_loss: 0.2757 - val_income_acc: 0.9453 - val_marital_acc: 0.9091
# ROC-AUC-income-Train: 0.9316 ROC-AUC-income-Validation: 0.9304 ROC-AUC-income-Test: 0.9286
# ROC-AUC-marital-Train: 0.9946 ROC-AUC-marital-Validation: 0.9684 ROC-AUC-marital-Test: 0.9672
# Epoch 94/100
# 199523/199523 [==============================] - 24s 122us/step - loss: 0.2340 - income_loss: 0.1372 - marital_loss: 0.0969 - income_acc: 0.9500 - marital_acc: 0.9581 - val_loss: 0.4260 - val_income_loss: 0.1429 - val_marital_loss: 0.2831 - val_income_acc: 0.9433 - val_marital_acc: 0.8961
# ROC-AUC-income-Train: 0.928 ROC-AUC-income-Validation: 0.9293 ROC-AUC-income-Test: 0.9282
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9606 ROC-AUC-marital-Test: 0.9592
# Epoch 95/100
# 199523/199523 [==============================] - 25s 125us/step - loss: 0.2397 - income_loss: 0.1420 - marital_loss: 0.0978 - income_acc: 0.9482 - marital_acc: 0.9582 - val_loss: 0.4453 - val_income_loss: 0.1525 - val_marital_loss: 0.2928 - val_income_acc: 0.9463 - val_marital_acc: 0.8862
# ROC-AUC-income-Train: 0.9176 ROC-AUC-income-Validation: 0.9212 ROC-AUC-income-Test: 0.9191
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9611 ROC-AUC-marital-Test: 0.9598
# Epoch 96/100
# 199523/199523 [==============================] - 25s 125us/step - loss: 0.2338 - income_loss: 0.1386 - marital_loss: 0.0952 - income_acc: 0.9496 - marital_acc: 0.9578 - val_loss: 0.4969 - val_income_loss: 0.1953 - val_marital_loss: 0.3016 - val_income_acc: 0.9428 - val_marital_acc: 0.8881
# ROC-AUC-income-Train: 0.8895 ROC-AUC-income-Validation: 0.8269 ROC-AUC-income-Test: 0.8307
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9613 ROC-AUC-marital-Test: 0.9598
# Epoch 97/100
# 199523/199523 [==============================] - 25s 125us/step - loss: 0.2338 - income_loss: 0.1385 - marital_loss: 0.0953 - income_acc: 0.9499 - marital_acc: 0.9580 - val_loss: 0.4104 - val_income_loss: 0.1456 - val_marital_loss: 0.2648 - val_income_acc: 0.9478 - val_marital_acc: 0.9077
# ROC-AUC-income-Train: 0.9287 ROC-AUC-income-Validation: 0.9304 ROC-AUC-income-Test: 0.9276
# ROC-AUC-marital-Train: 0.9944 ROC-AUC-marital-Validation: 0.9679 ROC-AUC-marital-Test: 0.9669
# Epoch 98/100
# 199523/199523 [==============================] - 25s 125us/step - loss: 0.2358 - income_loss: 0.1383 - marital_loss: 0.0975 - income_acc: 0.9489 - marital_acc: 0.9585 - val_loss: 0.4358 - val_income_loss: 0.1381 - val_marital_loss: 0.2977 - val_income_acc: 0.9497 - val_marital_acc: 0.8941
# ROC-AUC-income-Train: 0.94 ROC-AUC-income-Validation: 0.9363 ROC-AUC-income-Test: 0.9339
# ROC-AUC-marital-Train: 0.9925 ROC-AUC-marital-Validation: 0.9606 ROC-AUC-marital-Test: 0.9592
# Epoch 99/100
# 199523/199523 [==============================] - 25s 125us/step - loss: 0.2346 - income_loss: 0.1396 - marital_loss: 0.0950 - income_acc: 0.9495 - marital_acc: 0.9584 - val_loss: 0.4103 - val_income_loss: 0.1411 - val_marital_loss: 0.2693 - val_income_acc: 0.9511 - val_marital_acc: 0.9054
# ROC-AUC-income-Train: 0.9418 ROC-AUC-income-Validation: 0.9372 ROC-AUC-income-Test: 0.9355
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9634 ROC-AUC-marital-Test: 0.962
# Epoch 100/100
# 199523/199523 [==============================] - 25s 126us/step - loss: 0.2370 - income_loss: 0.1394 - marital_loss: 0.0976 - income_acc: 0.9477 - marital_acc: 0.9587 - val_loss: 0.4385 - val_income_loss: 0.1414 - val_marital_loss: 0.2971 - val_income_acc: 0.9508 - val_marital_acc: 0.9046
# ROC-AUC-income-Train: 0.9419 ROC-AUC-income-Validation: 0.9357 ROC-AUC-income-Test: 0.9343
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9622 ROC-AUC-marital-Test: 0.9606
